# %%
data_path = "C:\\Users\\colem\\Desktop\\Senior\\BigData\\GE_BigData_Project\\GE_Outcomes_V2\\Data\\Compliance\\GE_Compliance.csv"

import pandas as pd

dataframe = pd.DataFrame(pd.read_csv(data_path))

dataframe
# Out:
#               course_id  Assignments  Students outcome_1 outcome_2  \
# 0    FA2022_ARDE2020_01            0      36.0       HU1       NaN
# 1    FA2022_ARDE3250_01            0      24.0       HU1       NaN
# 2    FA2022_ARDE3340_01            0      16.0       HU1       NaN
# 3    FA2022_BIBL1100_01            0      43.0       CF1       NaN
# 4    FA2022_BIBL1100_02            0      43.0       CF1       NaN
# ..                  ...          ...       ...       ...       ...
# 286  SP2022_THEO3630_01            0      29.0       CF3       HU3
# 287  SP2022_THEO3710_01            0      23.0       CF3       NaN
# 288  SP2022_THEO3730_01            0      25.0       CF3       HU3
# 289  SP2022_THEO4900_01           12      13.0       HU2       NaN
# 290  SP2022_THEO4905_1R            0       7.0       HU2       NaN
#
#        teacher_#1_name   teacher_#1_email semester    course section  \
# 0         Jamie Tucker    JTucker@nnu.edu   FA2022  ARDE2020      01
# 1         Jamie Tucker    JTucker@nnu.edu   FA2022  ARDE3250      01
# 2            R Kinsman   PKinsman@nnu.edu   FA2022  ARDE3340      01
# 3         Mary Schmitt   MSchmitt@nnu.edu   FA2022  BIBL1100      01
# 4         Grant Miller   GTMiller@nnu.edu   FA2022  BIBL1100      02
# ..                 ...                ...      ...       ...     ...
# 286  Christina Smerick   CSmerick@nnu.edu   SP2022  THEO3630      01
# 287      Diane Leclerc  DKLeclerc@nnu.edu   SP2022  THEO3710      01
# 288         Joe Gorman   JTGorman@nnu.edu   SP2022  THEO3730      01
# 289      Diane Leclerc  DKLeclerc@nnu.edu   SP2022  THEO4900      01
# 290         Joe Gorman   JTGorman@nnu.edu   SP2022  THEO4905      1R
#
#                                         college Compliance  \
# 0                College of Arts and Humanities    Naughty
# 1                College of Arts and Humanities    Naughty
# 2                College of Arts and Humanities    Naughty
# 3    College of Theology and Christian Ministry    Naughty
# 4    College of Theology and Christian Ministry    Naughty
# ..                                          ...        ...
# 286  College of Theology and Christian Ministry    Naughty
# 287  College of Theology and Christian Ministry    Naughty
# 288  College of Theology and Christian Ministry    Naughty
# 289  College of Theology and Christian Ministry       Nice
# 290  College of Theology and Christian Ministry    Naughty
#
#                          Reason
# 0    Nothing Attached in Canvas
# 1    Nothing Attached in Canvas
# 2    Nothing Attached in Canvas
# 3    Nothing Attached in Canvas
# 4    Nothing Attached in Canvas
# ..                          ...
# 286  Nothing Attached in Canvas
# 287  Nothing Attached in Canvas
# 288  Nothing Attached in Canvas
# 289                   Compliant
# 290  Nothing Attached in Canvas
#
# [291 rows x 13 columns]

# %%
college_table = dataframe.pivot_table(index='college',values='Assignments')
college_table.plot(kind='bar', title='Average Number of Assignments per Course based on College')
# Out:
# <AxesSubplot:title={'center':'Average Number of Assignments per Course based on College'}, xlabel='college'>

# %%
students_table = dataframe.pivot_table(index='college',values='Students')
students_table.plot(kind='bar', title='Average Number of Students per Course based on College')
# Out:
# <AxesSubplot:title={'center':'Average Number of Students per Course based on College'}, xlabel='college'>
