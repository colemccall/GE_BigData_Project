# %%
import pandas as pd

file_path = 'C:\\Users\\colem\\Desktop\\Senior\\BigData\\GE_BigData_Project\\GE_Outcomes_V2\\Data\\Staging\\Combined\\All_Semesters_Registrar.csv'
dataframe = pd.DataFrame(pd.read_csv(file_path))

dataframe
# Out:
#      Unnamed: 0        Course_sis_id  \
# 0             0   FA2022_KINE1000_02
# 1             1   FA2022_BIBL1100_02
# 2             2   FA2022_EDUC3410_01
# 3             3   FA2022_HIST3390_01
# 4             4   FA2022_PHYS1110_01
# ..          ...                  ...
# 272         124   SP2022_EDUC3310_1L
# 273         125   SP2022_CRIM4010_01
# 274         126   SP2022_ENGR4972_01
# 275         127   SP2022_COMM2030_01
# 276         128  SP2022_ENGL1030B_02
#
#                                            Course_name  Number_of_students  \
# 0                  FUND OF WELLNESS FA2022_KINE1000_02                  46
# 1            INTRO BIBLICAL STUDIES FA2022_BIBL1100_02                  43
# 2    ENG LANG LRNRS/CONTNT LIT SECNDR FA2022_EDUC34...                  13
# 3                    RECENT AMERICA FA2022_HIST3390_01                  16
# 4                 COLLEGE PHYSICS I FA2022_PHYS1110_01                  24
# ..                                                 ...                 ...
# 272     TEACHING ENGLISH LANG LRNRS SP2022_EDUC3310_1L                   6
# 273                        CAPSTONE SP2022_CRIM4010_01                   9
# 274  SENIOR DESIGN PROJ II/CAPSTONE SP2022_ENGR4972_01                  12
# 275     INTERPERSONAL COMMUNICATION SP2022_COMM2030_01                  28
# 276  UNIVERSITY WRITING/RESEARCH B SP2022_ENGL1030B_02                  16
#
#     Outcome 1 Outcome 2  Teacher_#1_ID  Teacher_#1_name    Teacher_#1_email  \
# 0         SC4       NaN         371590      Kaydee Mick       KMick@nnu.edu
# 1         CF1       NaN         128337     Grant Miller    GTMiller@nnu.edu
# 2         HU3       NaN          10998    Jennifer Hill      JJHill@nnu.edu
# 3         HU4       NaN         669771  Matthew Millsap    MMillsap@nnu.edu
# 4         SC1       NaN          12433     Dan Lawrence  MDLawrence@nnu.edu
# ..        ...       ...            ...              ...                 ...
# 272       HU3       NaN          10998    Jennifer Hill      JJHill@nnu.edu
# 273       HU2       NaN          10702     Dean Matlock    DMatlock@nnu.edu
# 274       HU2       NaN         124939    Stephen Parke      SParke@nnu.edu
# 275       SC3       NaN         101387      Donna Allen     DMAllen@nnu.edu
# 276       IP4       NaN           8153   Roslyn Carlson    RCarlson@nnu.edu
#
#      Teacher_#2_ID  ... Teacher_#4_email Teacher_#5_ID  Teacher_#5_name  \
# 0              NaN  ...              NaN           NaN              NaN
# 1              NaN  ...              NaN           NaN              NaN
# 2              NaN  ...              NaN           NaN              NaN
# 3              NaN  ...              NaN           NaN              NaN
# 4              NaN  ...              NaN           NaN              NaN
# ..             ...  ...              ...           ...              ...
# 272            NaN  ...              NaN           NaN              NaN
# 273            NaN  ...              NaN           NaN              NaN
# 274       384174.0  ...              NaN           NaN              NaN
# 275            NaN  ...              NaN           NaN              NaN
# 276            NaN  ...              NaN           NaN              NaN
#
#     Teacher_#5_email Teacher_#6_ID  Teacher_#6_name Teacher_#6_email  \
# 0                NaN           NaN              NaN              NaN
# 1                NaN           NaN              NaN              NaN
# 2                NaN           NaN              NaN              NaN
# 3                NaN           NaN              NaN              NaN
# 4                NaN           NaN              NaN              NaN
# ..               ...           ...              ...              ...
# 272              NaN           NaN              NaN              NaN
# 273              NaN           NaN              NaN              NaN
# 274              NaN           NaN              NaN              NaN
# 275              NaN           NaN              NaN              NaN
# 276              NaN           NaN              NaN              NaN
#
#     Teacher_#7_ID  Teacher_#7_name Teacher_#7_email
# 0             NaN              NaN              NaN
# 1             NaN              NaN              NaN
# 2             NaN              NaN              NaN
# 3             NaN              NaN              NaN
# 4             NaN              NaN              NaN
# ..            ...              ...              ...
# 272           NaN              NaN              NaN
# 273           NaN              NaN              NaN
# 274           NaN              NaN              NaN
# 275           NaN              NaN              NaN
# 276           NaN              NaN              NaN
#
# [277 rows x 27 columns]

# %%
# Course Info
semester = []
course = []
section = []

# Colleges
college = []
theology = ['THEO', 'BIBL', 'PHIL', 'PRTH']
nat_sci = ['COMP', 'BIOL', 'CHEM', 'ENGR', 'PHYS', 'KINE', 'MILS']
art_hum = ['CLTA', 'COMM' , 'HUMN', 'ARDE', 'MUSC', 'ENGL', 'GEOG', 'POLS', 'HIST' , 'FREN', 'SPAN']
business = ['ECON', 'BSNS']
behav_social = ['PSYC', 'SOWK', 'CRIM']
education = ['EDUC']
nursing = ['NURS']

# For each of the rows
for index, rows in dataframe.iterrows():
    course_id = rows[1].split('_')
    
    semester.append(course_id[0])
    course.append(course_id[1])
    section.append(course_id[2])
    

    course_code = course_id[1][0:4]
    if(course_code in theology):
        college.append('College of Theology & Christian Ministry')
    elif(course_code in nat_sci):
        college.append('College of Natural and Applied Sciences')
    elif(course_code in art_hum or course_code == 'HNRS' or course_code == 'INTD'):
        college.append('College of Arts and Humanites')
    elif(course_code in business):
        college.append('College of Business')
    elif(course_code in behav_social):
        college.append('College of Behavior and Social Sciences')
    elif(course_code in education):
        college.append('College of Educaton')
    elif(course_code in nursing):
        college.append('College of Nursing')
    else:
        college.append('We dont know')

dataframe['Semester'] = semester
dataframe['Course'] = course
dataframe['Section'] = section
dataframe['College'] = college

dataframe.to_csv('C:\\Users\\colem\\Desktop\\Senior\\BigData\\GE_BigData_Project\\GE_Outcomes_V2\\Data\\Staging\\Cleaned\\Cleaned_Registrar_Data.csv')

dataframe
# Out:
#      Unnamed: 0        Course_sis_id  \
# 0             0   FA2022_KINE1000_02
# 1             1   FA2022_BIBL1100_02
# 2             2   FA2022_EDUC3410_01
# 3             3   FA2022_HIST3390_01
# 4             4   FA2022_PHYS1110_01
# ..          ...                  ...
# 272         124   SP2022_EDUC3310_1L
# 273         125   SP2022_CRIM4010_01
# 274         126   SP2022_ENGR4972_01
# 275         127   SP2022_COMM2030_01
# 276         128  SP2022_ENGL1030B_02
#
#                                            Course_name  Number_of_students  \
# 0                  FUND OF WELLNESS FA2022_KINE1000_02                  46
# 1            INTRO BIBLICAL STUDIES FA2022_BIBL1100_02                  43
# 2    ENG LANG LRNRS/CONTNT LIT SECNDR FA2022_EDUC34...                  13
# 3                    RECENT AMERICA FA2022_HIST3390_01                  16
# 4                 COLLEGE PHYSICS I FA2022_PHYS1110_01                  24
# ..                                                 ...                 ...
# 272     TEACHING ENGLISH LANG LRNRS SP2022_EDUC3310_1L                   6
# 273                        CAPSTONE SP2022_CRIM4010_01                   9
# 274  SENIOR DESIGN PROJ II/CAPSTONE SP2022_ENGR4972_01                  12
# 275     INTERPERSONAL COMMUNICATION SP2022_COMM2030_01                  28
# 276  UNIVERSITY WRITING/RESEARCH B SP2022_ENGL1030B_02                  16
#
#     Outcome 1 Outcome 2  Teacher_#1_ID  Teacher_#1_name    Teacher_#1_email  \
# 0         SC4       NaN         371590      Kaydee Mick       KMick@nnu.edu
# 1         CF1       NaN         128337     Grant Miller    GTMiller@nnu.edu
# 2         HU3       NaN          10998    Jennifer Hill      JJHill@nnu.edu
# 3         HU4       NaN         669771  Matthew Millsap    MMillsap@nnu.edu
# 4         SC1       NaN          12433     Dan Lawrence  MDLawrence@nnu.edu
# ..        ...       ...            ...              ...                 ...
# 272       HU3       NaN          10998    Jennifer Hill      JJHill@nnu.edu
# 273       HU2       NaN          10702     Dean Matlock    DMatlock@nnu.edu
# 274       HU2       NaN         124939    Stephen Parke      SParke@nnu.edu
# 275       SC3       NaN         101387      Donna Allen     DMAllen@nnu.edu
# 276       IP4       NaN           8153   Roslyn Carlson    RCarlson@nnu.edu
#
#      Teacher_#2_ID  ... Teacher_#6_ID Teacher_#6_name  Teacher_#6_email  \
# 0              NaN  ...           NaN             NaN               NaN
# 1              NaN  ...           NaN             NaN               NaN
# 2              NaN  ...           NaN             NaN               NaN
# 3              NaN  ...           NaN             NaN               NaN
# 4              NaN  ...           NaN             NaN               NaN
# ..             ...  ...           ...             ...               ...
# 272            NaN  ...           NaN             NaN               NaN
# 273            NaN  ...           NaN             NaN               NaN
# 274       384174.0  ...           NaN             NaN               NaN
# 275            NaN  ...           NaN             NaN               NaN
# 276            NaN  ...           NaN             NaN               NaN
#
#     Teacher_#7_ID Teacher_#7_name  Teacher_#7_email Semester     Course  \
# 0             NaN             NaN               NaN   FA2022   KINE1000
# 1             NaN             NaN               NaN   FA2022   BIBL1100
# 2             NaN             NaN               NaN   FA2022   EDUC3410
# 3             NaN             NaN               NaN   FA2022   HIST3390
# 4             NaN             NaN               NaN   FA2022   PHYS1110
# ..            ...             ...               ...      ...        ...
# 272           NaN             NaN               NaN   SP2022   EDUC3310
# 273           NaN             NaN               NaN   SP2022   CRIM4010
# 274           NaN             NaN               NaN   SP2022   ENGR4972
# 275           NaN             NaN               NaN   SP2022   COMM2030
# 276           NaN             NaN               NaN   SP2022  ENGL1030B
#
#      Section                                   College
# 0         02   College of Natural and Applied Sciences
# 1         02  College of Theology & Christian Ministry
# 2         01                       College of Educaton
# 3         01             College of Arts and Humanites
# 4         01   College of Natural and Applied Sciences
# ..       ...                                       ...
# 272       1L                       College of Educaton
# 273       01   College of Behavior and Social Sciences
# 274       01   College of Natural and Applied Sciences
# 275       01             College of Arts and Humanites
# 276       02             College of Arts and Humanites
#
# [277 rows x 31 columns]
