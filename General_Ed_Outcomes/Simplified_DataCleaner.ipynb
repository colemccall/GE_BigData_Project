# %% [markdown]
# ### Import Spring 2022 Data
#
# Starting off, we are going to use pandas to read the downloaded `Spring 2022 Outcome Report` to a dataframe. This cell will display that dataframe and give us an opportunity to take a first look at the data.

# %%
from Wrangling import loadDataFrame

file_path = '1_Landing\\Spring 2022 Outcome Report.csv'

dataframe = loadDataFrame(file_path)

# %% [markdown]
# ### Create and Export New Dataframe
# Since we have now cleaned and staged the data for visualization, we want to create a new dataframe, then save it as a .csv file

# %%
from Wrangling import cleanDataFrame


newData, cleanData = cleanDataFrame(dataframe)
newData.to_csv('2_Staging\\Spring 2022 Outcome Report 2.0.csv')
cleanData.to_csv('2_Staging\\Spring 2022 Outcome Report 2.1.csv')

# %% [markdown]
# ## Compare Old Data Frame to New Ones

# %%
dataframe
# Out:
#      student name  student id  student sis id  \
# 0             NaN       13328             NaN
# 1             NaN       17704             NaN
# 2             NaN       20155             NaN
# 3             NaN       21601             NaN
# 4             NaN       24034             NaN
# ...           ...         ...             ...
# 1494          NaN       40928             NaN
# 1495          NaN       41052             NaN
# 1496          NaN       41073             NaN
# 1497          NaN       41102             NaN
# 1498          NaN       41120             NaN
#
#                                        assessment title  assessment id  \
# 0     My Theology Paper:  Comparing and Contrasting ...         422281
# 1     My Theology Paper:  Comparing and Contrasting ...         422281
# 2     My Theology Paper:  Comparing and Contrasting ...         422281
# 3     My Theology Paper:  Comparing and Contrasting ...         422281
# 4     My Theology Paper:  Comparing and Contrasting ...         422281
# ...                                                 ...            ...
# 1494                         Argument Essay Final Draft         466450
# 1495                         Argument Essay Final Draft         464908
# 1496                         Argument Essay Final Draft         466450
# 1497                         Argument Essay Final Draft         466450
# 1498                                    Final Paper Due         467000
#
#      assessment type            submission date  submission score  \
# 0         assignment  2022-04-18T13:29:48-06:00             200.0
# 1         assignment  2022-05-01T21:26:54-06:00             160.0
# 2         assignment  2022-05-02T22:17:02-06:00             190.0
# 3         assignment  2022-05-02T22:36:29-06:00             180.0
# 4         assignment  2022-05-02T20:32:54-06:00             190.0
# ...              ...                        ...               ...
# 1494      assignment  2022-05-02T00:12:44-06:00             198.0
# 1495      assignment  2022-05-03T23:26:37-06:00             140.0
# 1496      assignment  2022-04-29T23:58:24-06:00             160.0
# 1497      assignment  2022-04-29T21:40:59-06:00             175.0
# 1498      assignment  2022-04-29T23:52:11-06:00             125.0
#
#                    learning outcome name  learning outcome id  ...  \
# 0     GE_CF2_U1415 Christian Formation 2                  400  ...
# 1     GE_CF2_U1415 Christian Formation 2                  400  ...
# 2     GE_CF2_U1415 Christian Formation 2                  400  ...
# 3     GE_CF2_U1415 Christian Formation 2                  400  ...
# 4     GE_CF2_U1415 Christian Formation 2                  400  ...
# ...                                  ...                  ...  ...
# 1494                        GE_IP4_U2021                 3647  ...
# 1495                        GE_IP4_U2021                 3647  ...
# 1496                        GE_IP4_U2021                 3647  ...
# 1497                        GE_IP4_U2021                 3647  ...
# 1498                        GE_IP4_U2021                 3647  ...
#
#                                          assignment url  \
# 0     https://nnu.instructure.com/courses/28474/assi...
# 1     https://nnu.instructure.com/courses/28474/assi...
# 2     https://nnu.instructure.com/courses/28474/assi...
# 3     https://nnu.instructure.com/courses/28474/assi...
# 4     https://nnu.instructure.com/courses/28474/assi...
# ...                                                 ...
# 1494  https://nnu.instructure.com/courses/28700/assi...
# 1495  https://nnu.instructure.com/courses/29652/assi...
# 1496  https://nnu.instructure.com/courses/28700/assi...
# 1497  https://nnu.instructure.com/courses/28700/assi...
# 1498  https://nnu.instructure.com/courses/28779/assi...
#
#            learning outcome friendly name  learning outcome points possible  \
# 0                   Christian Formation 2                               3.0
# 1                   Christian Formation 2                               3.0
# 2                   Christian Formation 2                               3.0
# 3                   Christian Formation 2                               3.0
# 4                   Christian Formation 2                               3.0
# ...                                   ...                               ...
# 1494  Intellectual and Practical Skills 4                               NaN
# 1495  Intellectual and Practical Skills 4                               NaN
# 1496  Intellectual and Practical Skills 4                               NaN
# 1497  Intellectual and Practical Skills 4                               NaN
# 1498  Intellectual and Practical Skills 4                               3.0
#
#       learning outcome mastery score learning outcome mastered  \
# 0                                2.0                       1.0
# 1                                2.0                       0.0
# 2                                2.0                       1.0
# 3                                2.0                       1.0
# 4                                2.0                       1.0
# ...                              ...                       ...
# 1494                             NaN                       1.0
# 1495                             NaN                       0.0
# 1496                             NaN                       1.0
# 1497                             NaN                       1.0
# 1498                             2.0                       0.0
#
#                                 learning outcome rating  \
# 0     Exemplary: Articulate distinctive characterist...
# 1     Minimum: List the characteristics of Wesleyan ...
# 2     Exemplary: Articulate distinctive characterist...
# 3     Target: Compare and contrast Wesleyan theology...
# 4     Exemplary: Articulate distinctive characterist...
# ...                                                 ...
# 1494  Exemplary:  Research multiple sources of infor...
# 1495                                    Outcome Not Met
# 1496  Target:  Research information in response to c...
# 1497  Target:  Research information in response to c...
# 1498  Minimum: Locate, access, and utilize informati...
#
#      learning outcome rating points account id  \
# 0                               3.0        107
# 1                               1.0        107
# 2                               3.0        107
# 3                               2.0        107
# 4                               3.0        107
# ...                             ...        ...
# 1494                            NaN         87
# 1495                            NaN         87
# 1496                            NaN         87
# 1497                            NaN         87
# 1498                            1.0         85
#
#                                account name  enrollment state
# 0     Undergraduate Philosophy and Religion            active
# 1     Undergraduate Philosophy and Religion            active
# 2     Undergraduate Philosophy and Religion            active
# 3     Undergraduate Philosophy and Religion            active
# 4     Undergraduate Philosophy and Religion            active
# ...                                     ...               ...
# 1494           Undergraduate Langauge & Lit            active
# 1495           Undergraduate Langauge & Lit            active
# 1496           Undergraduate Langauge & Lit            active
# 1497           Undergraduate Langauge & Lit            active
# 1498               Undergraduate Humanities            active
#
# [1499 rows x 30 columns]

# %%
newData
# Out:
#       submission_date  assignment outcome code outcome year  \
# 13328      2022-04-18      422281          CF2        U1415
# 17704      2022-05-01      422281          CF2        U1415
# 20155      2022-05-02      422281          CF2        U1415
# 21601      2022-05-02      422281          CF2        U1415
# 24034      2022-05-02      422281          CF2        U1415
# ...               ...         ...          ...          ...
# 40928      2022-05-02      466450          IP4        U2021
# 41052      2022-05-03      464908          IP4        U2021
# 41073      2022-04-29      466450          IP4        U2021
# 41102      2022-04-29      466450          IP4        U2021
# 41120      2022-04-29      467000          IP4        U2021
#
#                  course_id semester     course section   outcome rating  \
# 13328   SP2022_THEO2100_03   SP2022   THEO2100      03        Exemplary
# 17704   SP2022_THEO2100_03   SP2022   THEO2100      03          Minimum
# 20155   SP2022_THEO2100_03   SP2022   THEO2100      03        Exemplary
# 21601   SP2022_THEO2100_03   SP2022   THEO2100      03           Target
# 24034   SP2022_THEO2100_03   SP2022   THEO2100      03        Exemplary
# ...                    ...      ...        ...     ...              ...
# 40928  SP2022_ENGL1030B_02   SP2022  ENGL1030B      02        Exemplary
# 41052  SP2022_ENGL1030B_01   SP2022  ENGL1030B      01  Outcome Not Met
# 41073  SP2022_ENGL1030B_02   SP2022  ENGL1030B      02           Target
# 41102  SP2022_ENGL1030B_02   SP2022  ENGL1030B      02           Target
# 41120   SP2022_HNRS2560_01   SP2022   HNRS2560      01          Minimum
#
#        outcome score  corrected outcome score corrected outcome rating  \
# 13328            3.0                      3.0                Exemplary
# 17704            1.0                      1.0                  Minimum
# 20155            3.0                      3.0                Exemplary
# 21601            2.0                      2.0                   Target
# 24034            3.0                      3.0                Exemplary
# ...              ...                      ...                      ...
# 40928            NaN                      3.0                Exemplary
# 41052            NaN                      0.0                     Fail
# 41073            NaN                      2.0                   Target
# 41102            NaN                      2.0                   Target
# 41120            1.0                      1.0                  Minimum
#
#                                         college        compliance
# 13328  College of Theology & Christian Ministry  Outcome assessed
# 17704  College of Theology & Christian Ministry  Outcome assessed
# 20155  College of Theology & Christian Ministry  Outcome assessed
# 21601  College of Theology & Christian Ministry  Outcome assessed
# 24034  College of Theology & Christian Ministry  Outcome assessed
# ...                                         ...               ...
# 40928             College of Arts and Humanites  Outcome assessed
# 41052             College of Arts and Humanites  Outcome assessed
# 41073             College of Arts and Humanites  Outcome assessed
# 41102             College of Arts and Humanites  Outcome assessed
# 41120             College of Arts and Humanites  Outcome assessed
#
# [1499 rows x 14 columns]

# %%
cleanData
# Out:
#       submission_date  assignment code outcome code outcome year semester  \
# 13328      2022-04-18           422281          CF2        U1415   SP2022
# 17704      2022-05-01           422281          CF2        U1415   SP2022
# 20155      2022-05-02           422281          CF2        U1415   SP2022
# 21601      2022-05-02           422281          CF2        U1415   SP2022
# 24034      2022-05-02           422281          CF2        U1415   SP2022
# ...               ...              ...          ...          ...      ...
# 40928      2022-05-02           466450          IP4        U2021   SP2022
# 41052      2022-05-03           464908          IP4        U2021   SP2022
# 41073      2022-04-29           466450          IP4        U2021   SP2022
# 41102      2022-04-29           466450          IP4        U2021   SP2022
# 41120      2022-04-29           467000          IP4        U2021   SP2022
#
#           course section  outcome score outcome rating  \
# 13328   THEO2100      03            3.0      Exemplary
# 17704   THEO2100      03            1.0        Minimum
# 20155   THEO2100      03            3.0      Exemplary
# 21601   THEO2100      03            2.0         Target
# 24034   THEO2100      03            3.0      Exemplary
# ...          ...     ...            ...            ...
# 40928  ENGL1030B      02            3.0      Exemplary
# 41052  ENGL1030B      01            0.0           Fail
# 41073  ENGL1030B      02            2.0         Target
# 41102  ENGL1030B      02            2.0         Target
# 41120   HNRS2560      01            1.0        Minimum
#
#                                         college        compliance
# 13328  College of Theology & Christian Ministry  Outcome assessed
# 17704  College of Theology & Christian Ministry  Outcome assessed
# 20155  College of Theology & Christian Ministry  Outcome assessed
# 21601  College of Theology & Christian Ministry  Outcome assessed
# 24034  College of Theology & Christian Ministry  Outcome assessed
# ...                                         ...               ...
# 40928             College of Arts and Humanites  Outcome assessed
# 41052             College of Arts and Humanites  Outcome assessed
# 41073             College of Arts and Humanites  Outcome assessed
# 41102             College of Arts and Humanites  Outcome assessed
# 41120             College of Arts and Humanites  Outcome assessed
#
# [1499 rows x 11 columns]

# %% [markdown]
# ## Check how many courses that we actually have data for

# %%
from Wrangling import test
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_24032/1805975057.py in <module>
# ----> 1 from Wrangling import test
#
# ImportError: cannot import name 'test' from 'Wrangling' (c:\Users\colem\Desktop\Senior\BigData\GE_BigData_Project\General_Ed_Outcomes\Wrangling.py)

# %%
from Wrangling import readCourseInfo

alignment_path = '1_Landing\\GE Outcome_Course Alignment Worksheet.xlsx'
ge_alignment = readCourseInfo(alignment_path, cleanData)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_24032/1196173093.py in <module>
# ----> 1 from Wrangling import readCourseInfo
#       2
#       3 alignment_path = '1_Landing\\GE Outcome_Course Alignment Worksheet.xlsx'
#       4 ge_alignment = readCourseInfo(alignment_path, cleanData)
#
# ImportError: cannot import name 'readCourseInfo' from 'Wrangling' (c:\Users\colem\Desktop\Senior\BigData\GE_BigData_Project\General_Ed_Outcomes\Wrangling.py)
