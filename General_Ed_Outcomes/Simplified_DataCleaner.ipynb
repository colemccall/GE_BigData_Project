# %% [markdown]
# ### Import Spring 2022 Data
#
# Starting off, we are going to use pandas to read the downloaded `Spring 2022 Outcome Report` to a dataframe. This cell will display that dataframe and give us an opportunity to take a first look at the data.

# %%
from Code.Wrangling import loadDataFrame

file_path = '\\1_Landing\\Spring 2022 Outcome Report.csv'

dataframe = loadDataFrame(file_path)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_24032/3168085599.py in <module>
# ----> 1 from Code.Wrangling import loadDataFrame
#       2
#       3 file_path = '\\1_Landing\\Spring 2022 Outcome Report.csv'
#       4
#       5 dataframe = loadDataFrame(file_path)
#
# ImportError: cannot import name 'loadDataFrame' from 'Code.Wrangling' (c:\Users\colem\Desktop\Senior\BigData\GE_BigData_Project\General_Ed_Outcomes\Code\Wrangling.py)

# %% [markdown]
# ### Create and Export New Dataframe
# Since we have now cleaned and staged the data for visualization, we want to create a new dataframe, then save it as a .csv file

# %%
from Code.Wrangling import cleanDataFrame


newData, cleanData = cleanDataFrame(dataframe)
newData.to_csv('2_Staging\\Spring 2022 Outcome Report 2.0.csv')
cleanData.to_csv('2_Staging\\Spring 2022 Outcome Report 2.1.csv')

# %% [markdown]
# ## Check how many courses that we actually have data for

# %%
import os

alignment_path = os.getcwd() + '\\1_Landing\\GE Outcome_Course Alignment Worksheet.xlsx'

ge_alignment = pd.read_excel(alignment_path)

ge_alignment
# Out:
#    General Education Outcome/Course Alignment by Outcomes TUG  \
# 0   Directions: Find the outcome and then search i...
# 1                                                 CF1
# 2                                            BIBL1100
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30                                                NaN
# 31                                                NaN
# 32                                                NaN
# 33                                                NaN
# 34                                                NaN
# 35                                                NaN
# 36                                                NaN
# 37                                                NaN
# 38                                                NaN
# 39                                                NaN
# 40                                                NaN
# 41                                                NaN
# 42                                                NaN
# 43                                                NaN
#
#                                   Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4  \
# 0                                        NaN        NaN        NaN        NaN
# 1                                        CF2        CF3        CF4        SC1
# 2                                   THEO2100   BIBL3220   HNRS2550   BIOL1010
# 3                                        NaN   BIBL3230   PHIL2010  BIOL1030
# 4                                        NaN   BIBL3260   PHIL2020   BIOL1040
# 5                                        NaN   BIBL3270  PHIL2030    BIOL1060
# 6                                        NaN   BIBL3810   PHIL3010   BIOL2010
# 7                                        NaN   HNRS3560   PHIL3080   BIOL2030
# 8                                        NaN   THEO3410   PHIL3520   BIOL2220
# 9                                        NaN   THEO3540   PHIL3600   BIOL2230
# 10                                       NaN   THEO3560   PHIL3620   BIOL2300
# 11                                       NaN   THEO3580        NaN   BIOL2320
# 12                                       NaN   THEO3590        NaN   BIOL3250
# 13                                       NaN   THEO3620        NaN   CHEM1210
# 14                                       NaN   THEO3630        NaN   CHEM2210
# 15                                       NaN   THEO3640        NaN   CHEM2220
# 16                                       NaN   THEO3710        NaN   COMP3230
# 17                                       NaN   THEO3730        NaN   HNRS3550
# 18                                       NaN   THEO3740        NaN   INTD3550
# 19                                       NaN        NaN        NaN   PHYS1010
# 20                                       NaN        NaN        NaN   PHYS1060
# 21                                       NaN        NaN        NaN   PHYS1110
# 22                                       NaN        NaN        NaN   PHYS1120
# 23                                       NaN        NaN        NaN   PHYS2110
# 24                                       NaN        NaN        NaN   PHYS2120
# 25                                       NaN        NaN        NaN   PSYC3850
# 26                                       NaN        NaN        NaN        NaN
# 27                                       NaN        NaN        NaN        NaN
# 28                                       NaN        NaN        NaN        NaN
# 29                                       NaN        NaN        NaN        NaN
# 30                                       NaN        NaN        NaN        NaN
# 31                                       NaN        NaN        NaN        NaN
# 32                                       NaN        NaN        NaN        NaN
# 33                                       NaN        NaN        NaN        NaN
# 34                                       NaN        NaN        NaN        NaN
# 35                                       NaN        NaN        NaN        NaN
# 36                                       Key        NaN        NaN        NaN
# 37              College of Arts & Humanities        NaN        NaN        NaN
# 38     College of Behavior & Social Sciences        NaN        NaN        NaN
# 39                       College of Business        NaN        NaN        NaN
# 40                      College of Education        NaN        NaN        NaN
# 41     College of Natural & Applied Sciences        NaN        NaN        NaN
# 42                        College of Nursing        NaN        NaN        NaN
# 43  College of Theology & Christian Ministry        NaN        NaN        NaN
#
#    Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9 Unnamed: 10  \
# 0         NaN        NaN        NaN        NaN        NaN         NaN
# 1         SC2        SC3        SC4        HU1        HU2         HU3
# 2   BIOL1010L   CLTA1550   KINE1000   ARDE2020   HUMN1020    BIBL3810
# 3   BIOL1030L   CLTA3180   KINE1010   ARDE3250   HNRS2550    BIOL1030
# 4   BIOL1040L   COMM2030   KINE1020   ARDE3340   ARDE4950   BIOL3520L
# 5   BIOL1060L   COMM3200   KINE1030   ARDE3750   BIOL4970    BSNS4600
# 6   BIOL2010L   ECON1050   KINE2640   ARDE3950   BIOL4980    CLTA1550
# 7   BIOL2030L   ECON2010   KINE2770   MUSC1010   BSNS4980    CLTA3180
# 8   BIOL2220L   ECON2410   MILS2500   MUSC2020   CHEM4980    COMM1050
# 9   BIOL2230L   ECON2420        NaN   MUSC3260   COMM4980    COMM3200
# 10  BIOL3250L   ECON3010        NaN   MUSC3270   COMP4980    EDUC2250
# 11  CHEM1210L   EDUC2110        NaN   ENGL2210   CRIM4010    EDUC3310
# 12  CHEM2210L   ENGR3410        NaN   ENGL2220  EDUC4950.    EDUC3410
# 13  CHEM2220L   GEOG1050        NaN   ENGL2310   ENGL4980   ENGL3015A
# 14  CHEM2210L   HNRS3560        NaN   ENGL2320   ENGR4972   ENGL3015J
# 15  CHEM2220L   POLS1010        NaN   ENGL2410   HIST4970  ENGL4270/W
# 16  PHYS1010L   POLS1030        NaN   ENGL2420   HUMN4010    FREN1010
# 17  PHYS1060L   POLS1050        NaN   ENGL2430   KINE4970    FREN1020
# 18  PHYS1110L   PSYC1550        NaN   ENGL3210   MATH4100    HUMN1060
# 19  PHYS1120L   PSYC2100        NaN   ENGL3250   MUSC4000    HIST3840
# 20  PHYS2110L   PSYC2110        NaN   ENGL3310   NURS4040    MILS3900
# 21  PHYS2120L        NaN        NaN   ENGL3320   PHIL4900    NURS4010
# 22  PSYC3850L        NaN        NaN   ENGL3350   PHYS4980    PRTH2420
# 23        NaN        NaN        NaN   ENGL3410   POLS4970    PSYC4112
# 24        NaN        NaN        NaN   ENGL3420   PSYC4010    SOWK2851
# 25        NaN        NaN        NaN   ENGL3510   SOWK4981    SOWK2970
# 26        NaN        NaN        NaN   ENGL3520   SPAN4010    SPAN1010
# 27        NaN        NaN        NaN   ENGL3750   THEO4900    SPAN1020
# 28        NaN        NaN        NaN   ENGL4270        NaN    SPAN2010
# 29        NaN        NaN        NaN   ENGL4340        NaN    SPAN2020
# 30        NaN        NaN        NaN   ENGL4350        NaN    SPAN3010
# 31        NaN        NaN        NaN   HNRS3550        NaN    SPAN3310
# 32        NaN        NaN        NaN        NaN        NaN    THEO3630
# 33        NaN        NaN        NaN        NaN        NaN    THEO3640
# 34        NaN        NaN        NaN        NaN        NaN    THEO3730
# 35        NaN        NaN        NaN        NaN        NaN         NaN
# 36        NaN        NaN        NaN        NaN        NaN         NaN
# 37        NaN        NaN        NaN        NaN        NaN         NaN
# 38        NaN        NaN        NaN        NaN        NaN         NaN
# 39        NaN        NaN        NaN        NaN        NaN         NaN
# 40        NaN        NaN        NaN        NaN        NaN         NaN
# 41        NaN        NaN        NaN        NaN        NaN         NaN
# 42        NaN        NaN        NaN        NaN        NaN         NaN
# 43        NaN        NaN        NaN        NaN        NaN         NaN
#
#    Unnamed: 11 Unnamed: 12 Unnamed: 13 Unnamed: 14 Unnamed: 15
# 0          NaN         NaN         NaN         NaN         NaN
# 1          HU4         IP1         IP2         IP3         IP4
# 2     HIST1030    COMM1210    ENGL3015    BSNS2330   ENGL1030A
# 3     HIST1040    COMM3211   ENGL2610W    COMP1220   ENGL1030B
# 4     HIST1070         NaN   ENGL3020W    KINE4520    HNRS2560
# 5     HIST2030         NaN   ENGL3040W    MATH1100         NaN
# 6     HIST2040         NaN   ENGL3210W    MATH1300         NaN
# 7     HIST3390         NaN   ENGL3250W    MATH1400         NaN
# 8     HIST3480         NaN   ENGL3310W    MATH2010         NaN
# 9     HNRS2560         NaN   ENGL3320W    MATH2240         NaN
# 10         NaN         NaN   ENGL3350W    MATH2310         NaN
# 11         NaN         NaN   ENGL3420W    PSYC3640         NaN
# 12         NaN         NaN   ENGL4270W         NaN         NaN
# 13         NaN         NaN   ENGL4340W         NaN         NaN
# 14         NaN         NaN   ENGL4350W         NaN         NaN
# 15         NaN         NaN         NaN         NaN         NaN
# 16         NaN         NaN         NaN         NaN         NaN
# 17         NaN         NaN         NaN         NaN         NaN
# 18         NaN         NaN         NaN         NaN         NaN
# 19         NaN         NaN         NaN         NaN         NaN
# 20         NaN         NaN         NaN         NaN         NaN
# 21         NaN         NaN         NaN         NaN         NaN
# 22         NaN         NaN         NaN         NaN         NaN
# 23         NaN         NaN         NaN         NaN         NaN
# 24         NaN         NaN         NaN         NaN         NaN
# 25         NaN         NaN         NaN         NaN         NaN
# 26         NaN         NaN         NaN         NaN         NaN
# 27         NaN         NaN         NaN         NaN         NaN
# 28         NaN         NaN         NaN         NaN         NaN
# 29         NaN         NaN         NaN         NaN         NaN
# 30         NaN         NaN         NaN         NaN         NaN
# 31         NaN         NaN         NaN         NaN         NaN
# 32         NaN         NaN         NaN         NaN         NaN
# 33         NaN         NaN         NaN         NaN         NaN
# 34         NaN         NaN         NaN         NaN         NaN
# 35         NaN         NaN         NaN         NaN         NaN
# 36         NaN         NaN         NaN         NaN         NaN
# 37         NaN         NaN         NaN         NaN         NaN
# 38         NaN         NaN         NaN         NaN         NaN
# 39         NaN         NaN         NaN         NaN         NaN
# 40         NaN         NaN         NaN         NaN         NaN
# 41         NaN         NaN         NaN         NaN         NaN
# 42         NaN         NaN         NaN         NaN         NaN
# 43         NaN         NaN         NaN         NaN         NaN

# %%
list_of_courses = []

for (index_label, row_series) in ge_alignment.iterrows():
    for value in row_series.values:
        if(len(str(value)) > 4 and len(str(value)) < 12):
            if str(value) not in list_of_courses:
                list_of_courses.append(str(value))

# %%
assessed_courses = []

for (index_label, row_series) in coles_format.iterrows():
    if(row_series[4] in list_of_courses and row_series[4] not in assessed_courses):
        assessed_courses.append(str(row_series[4]))

print(list_of_courses)
print(assessed_courses)

print(str(len(assessed_courses)) + ' out of ' + str(len(list_of_courses)) + ' courses have been assessed')
# Out:
# ['BIBL1100', 'THEO2100', 'BIBL3220', 'HNRS2550', 'BIOL1010', 'BIOL1010L', 'CLTA1550', 'KINE1000', 'ARDE2020', 'HUMN1020', 'BIBL3810', 'HIST1030', 'COMM1210', 'ENGL3015', 'BSNS2330', 'ENGL1030A', 'BIBL3230', 'PHIL2010', 'BIOL1030 ', 'BIOL1030L', 'CLTA3180', 'KINE1010', 'ARDE3250', 'BIOL1030', 'HIST1040', 'COMM3211', 'ENGL2610W', 'COMP1220', 'ENGL1030B', 'BIBL3260', 'PHIL2020', 'BIOL1040', 'BIOL1040L', 'COMM2030', 'KINE1020', 'ARDE3340', 'ARDE4950', 'BIOL3520L', 'HIST1070', 'ENGL3020W', 'KINE4520', 'HNRS2560', 'BIBL3270', 'PHIL2030 ', 'BIOL1060', 'BIOL1060L', 'COMM3200', 'KINE1030', 'ARDE3750', 'BIOL4970', 'BSNS4600', 'HIST2030', 'ENGL3040W', 'MATH1100', 'PHIL3010', 'BIOL2010', 'BIOL2010L', 'ECON1050', 'KINE2640', 'ARDE3950', 'BIOL4980', 'HIST2040', 'ENGL3210W', 'MATH1300', 'HNRS3560', 'PHIL3080', 'BI