# %%
import os, pandas as pd

## Set the canvas landing path
canvas_path = os.getcwd() + '\\1_Landing\\Canvas'
canvas_files = os.listdir(canvas_path)

frames = []

## Create a dataframe for each file in the canvas landing path
for name in canvas_files:
    file_path = (canvas_path + '\\' + name)
    df = pd.read_csv(file_path)
    frames.append(df)


## Combine dataframes from each semester and show it
result = pd.concat(frames)
semester_canvas_data_path = os.getcwd() + '\\2_Staging\\Combined\\All_Semesters.csv'
result.to_csv(semester_canvas_data_path)
result
# Out:
#      student name  student id  student sis id              assessment title  \
# 0             NaN        5010             NaN  CAP paper 1 Prompt / Dropbox
# 1             NaN        5010             NaN  CAP paper 2 Prompt / Dropbox
# 2             NaN        5010             NaN  CAP paper 4 Prompt / Dropbox
# 3             NaN        7652             NaN  CAP paper 1 Prompt / Dropbox
# 4             NaN        7652             NaN  CAP paper 2 Prompt / Dropbox
# ...           ...         ...             ...                           ...
# 1494          NaN       40928             NaN    Argument Essay Final Draft
# 1495          NaN       41052             NaN    Argument Essay Final Draft
# 1496          NaN       41073             NaN    Argument Essay Final Draft
# 1497          NaN       41102             NaN    Argument Essay Final Draft
# 1498          NaN       41120             NaN               Final Paper Due
#
#       assessment id assessment type            submission date  \
# 0            480772      assignment  2022-09-11T14:25:19-06:00
# 1            480773      assignment  2022-09-16T10:46:01-06:00
# 2            480775      assignment  2022-09-29T15:05:44-06:00
# 3            480772      assignment  2022-09-10T19:13:42-06:00
# 4            480773      assignment  2022-09-18T19:32:21-06:00
# ...             ...             ...                        ...
# 1494         466450      assignment  2022-05-02T00:12:44-06:00
# 1495         464908      assignment  2022-05-03T23:26:37-06:00
# 1496         466450      assignment  2022-04-29T23:58:24-06:00
# 1497         466450      assignment  2022-04-29T21:40:59-06:00
# 1498         467000      assignment  2022-04-29T23:52:11-06:00
#
#       submission score               learning outcome name  \
# 0                 42.0  GE_CF4_U1516 Christian Formation 4
# 1                 38.0  GE_CF4_U1516 Christian Formation 4
# 2                 37.5  GE_CF4_U1516 Christian Formation 4
# 3                 33.0  GE_CF4_U1516 Christian Formation 4
# 4                 36.0  GE_CF4_U1516 Christian Formation 4
# ...                ...                                 ...
# 1494             198.0                        GE_IP4_U2021
# 1495             140.0                        GE_IP4_U2021
# 1496             160.0                        GE_IP4_U2021
# 1497             175.0                        GE_IP4_U2021
# 1498             125.0                        GE_IP4_U2021
#
#       learning outcome id  ...  \
# 0                     637  ...
# 1                     637  ...
# 2                     637  ...
# 3                     637  ...
# 4                     637  ...
# ...                   ...  ...
# 1494                 3647  ...
# 1495                 3647  ...
# 1496                 3647  ...
# 1497                 3647  ...
# 1498                 3647  ...
#
#                                          assignment url  \
# 0     https://nnu.instructure.com/courses/30102/assi...
# 1     https://nnu.instructure.com/courses/30102/assi...
# 2     https://nnu.instructure.com/courses/30102/assi...
# 3     https://nnu.instructure.com/courses/30102/assi...
# 4     https://nnu.instructure.com/courses/30102/assi...
# ...                                                 ...
# 1494  https://nnu.instructure.com/courses/28700/assi...
# 1495  https://nnu.instructure.com/courses/29652/assi...
# 1496  https://nnu.instructure.com/courses/28700/assi...
# 1497  https://nnu.instructure.com/courses/28700/assi...
# 1498  https://nnu.instructure.com/courses/28779/assi...
#
#            learning outcome friendly name  learning outcome points possible  \
# 0                                     NaN                               3.0
# 1                                     NaN                               3.0
# 2                                     NaN                               3.0
# 3                                     NaN                               3.0
# 4                                     NaN                               3.0
# ...                                   ...                               ...
# 1494  Intellectual and Practical Skills 4                               NaN
# 1495  Intellectual and Practical Skills 4                               NaN
# 1496  Intellectual and Practical Skills 4                               NaN
# 1497  Intellectual and Practical Skills 4                               NaN
# 1498  Intellectual and Practical Skills 4                               3.0
#
#       learning outcome mastery score learning outcome mastered  \
# 0                                2.0                       1.0
# 1                                2.0                       0.0
# 2                                2.0                       0.0
# 3                                2.0                       0.0
# 4                                2.0                       0.0
# ...                              ...                       ...
# 1494                             NaN                       1.0
# 1495                             NaN                       0.0
# 1496                             NaN                       1.0
# 1497                             NaN                       1.0
# 1498                             2.0                       0.0
#
#                                 learning outcome rating  \
# 0     Target: Construct a cogent inductive or sound ...
# 1     Minimum: Construct an inductive or deductive a...
# 2     Minimum: Construct an inductive or deductive a...
# 3     Minimum: Construct an inductive or deductive a...
# 4                                      Outcome not met.
# ...                                                 ...
# 1494  Exemplary:  Research multiple sources of infor...
# 1495                                    Outcome Not Met
# 1496  Target:  Research information in response to c...
# 1497  Target:  Research information in response to c...
# 1498  Minimum: Locate, access, and utilize informati...
#
#      learning outcome rating points account id                  account name  \
# 0                               2.0        322                  Religion_CMO
# 1                               1.0        322                  Religion_CMO
# 2                               1.0        322                  Religion_CMO
# 3                               1.0        322                  Religion_CMO
# 4                               0.0        322                  Religion_CMO
# ...                             ...        ...                           ...
# 1494                            NaN         87  Undergraduate Langauge & Lit
# 1495                            NaN         87  Undergraduate Langauge & Lit
# 1496                            NaN         87  Undergraduate Langauge & Lit
# 1497                            NaN         87  Undergraduate Langauge & Lit
# 1498                            1.0         85      Undergraduate Humanities
#
#       enrollment state
# 0               active
# 1               active
# 2               active
# 3               active
# 4               active
# ...                ...
# 1494            active
# 1495            active
# 1496            active
# 1497            active
# 1498            active
#
# [1712 rows x 30 columns]
